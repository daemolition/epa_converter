# %%
import os
import pandas as pd

path = os.path.abspath(os.path.join('Katologübersicht.csv'))

data = pd.read_csv(path, delimiter=",")

new_data = data[['Katalog', 'CODE', 'Klarname']].copy()
new_data

# %%
pivot_table = new_data.pivot(index=["CODE","Klarname"], columns="Katalog").reset_index()
pivot_table
# Out:
#                                CODE                    Klarname
# Katalog
# 0                               NaN                 Automatisch
# 1              ABRECHNUNGSDOKUMENTE        Abrechnungsdokumente
# 2                ACCIDENT_EMERGENCY          ACCIDENT_EMERGENCY
# 3        ADMINISTRATIVE_CHECKLISTEN  Administrative Checklisten
# 4                ADMINISTRATIVE_DOC    Administratives Dokument
# ..                              ...                         ...
# 290                 VERY_RESTRICTED          sehr eingeschränkt
# 291                      VIDEO_DATA                  Videodaten
# 292               VISZERALCHIRURGIE           Viszeralchirurgie
# 293               WUNDDOKUMENTATION           Wunddokumentation
# 294                     ZAHNMEDIZIN                 Zahnmedizin
#
# [295 rows x 2 columns]
